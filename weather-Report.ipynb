# %%
## Clean the null values and find the mean temperature using NumPy,
## Plot a line chart using Date and Temperature, and draw the mean line in red color From the Weather Data?

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# imported data from file using Pandas

df = pd.read_csv('nyc_weather.csv')
df.head()
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0  01-01-2016           38        23        52                 30.03
# 1  01-02-2016           36        18        46                 30.02
# 2  01-03-2016           40        21        47                 29.86
# 3  01-04-2016           25         9        44                 30.05
# 4  01-05-2016           20        -3        41                 30.57
#
#    VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 0               10             8               0           5    NaN
# 1               10             7               0           3    NaN
# 2               10             8               0           1    NaN
# 3               10             9               0           3    NaN
# 4               10             5               0           0    NaN
#
#    WindDirDegrees
# 0             281
# 1             275
# 2             277
# 3             345
# 4             333

# %%
## finding the Null values

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31 entries, 0 to 30
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   EST                   31 non-null     object
#  1   Temperature           31 non-null     int64
#  2   DewPoint              31 non-null     int64
#  3   Humidity              31 non-null     int64
#  4   Sea Level PressureIn  31 non-null     float64
#  5   VisibilityMiles       31 non-null     int64
#  6   WindSpeedMPH          31 non-null     int64
#  7   PrecipitationIn       31 non-null     object
#  8   CloudCover            31 non-null     int64
#  9   Events                9 non-null      object
#  10  WindDirDegrees        31 non-null     int64
# dtypes: float64(1), int64(7), object(3)
# memory usage: 2.8+ KB

# %%
# Droping the null value Columns

df.drop("Events", axis=1, inplace=True)

# %%
# Verify the data

df.head(2)
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0  01-01-2016           38        23        52                 30.03
# 1  01-02-2016           36        18        46                 30.02
#
#    VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover  WindDirDegrees
# 0               10             8               0           5             281
# 1               10             7               0           3             275

# %%
# Adding the values to the variable to plot the Line chart

x1 = df["EST"]
y = df["Temperature"]

# %%
# Changing the Date Formate

x1 = pd.to_datetime(x)
x_formatted = x.dt.day
x = x_formatted

# %%
# Plot the line chart for temperature over dates

plt.plot(x,y)
plt.xlabel("Date")
plt.ylabel("Temperature")
plt.title("Temperature in India")
plt.show()

# %%
# Find mean of each numeric column

df.describe()
# Out:
#        Temperature   DewPoint   Humidity  Sea Level PressureIn  \
# count    31.000000  31.000000  31.000000             31.000000
# mean     34.677419  17.838710  51.677419             29.992903
# std       7.639315  11.378626  11.634395              0.237237
# min      20.000000  -3.000000  33.000000             29.520000
# 25%      29.000000  10.000000  44.500000             29.855000
# 50%      35.000000  18.000000  50.000000             30.010000
# 75%      39.500000  23.000000  55.000000             30.140000
# max      50.000000  46.000000  78.000000             30.570000
#
#        VisibilityMiles  WindSpeedMPH  CloudCover  WindDirDegrees
# count        31.000000     31.000000   31.000000       31.000000
# mean          9.193548      6.903226    3.129032      247.129032
# std           1.939405      2.724639    2.629853       92.308086
# min           1.000000      2.000000    0.000000       34.000000
# 25%           9.000000      5.000000    1.000000      238.000000
# ...

# %%
# Plot the line chart with mean value for temperature over dates

plt.plot(x,y)
plt.axhline(y= 34.6, color='red', linestyle='--')
plt.xlabel("Date")
plt.ylabel("Temperature")
plt.title("Temperature in India")
plt.show()
